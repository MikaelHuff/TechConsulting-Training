# %%
from datetime import datetime

# %%
def generate_report(time_log, morning_study, training, afternoon_study, challenges, plan_tomorrow, additional_notes='None'):

    report = '**Daily Activity Report**\n'
    report += datetime.today().strftime('%m/%d/%y') + '\n'
    report += 'Name: Mikael Huff\n'
    report += 'Technology: Data Science (DS)\n'
    report += 'CDM: Divesh Gupta\n\n'

    report += '🕒 **Time Log & Activities**\n' 
    report += time_log + '\n\n'
    
    report += '✅ **Summary of Work Done**\n'
    if morning_study != '':
        report += f'Morning Self-study:\n{morning_study}\n\n'
    report += f'Training:\n{training}\n\n'
    report += f'Afternoon Self-study:\n{afternoon_study}\n\n'

    report +='🚧 **Issues/Challenges Faced**'
    report += f'\n{challenges}\n\n'

    if plan_tomorrow != '':
        report += '📅 **Plan for Tomorrow**\n'
        report += f'{plan_tomorrow}\n\n'

    report += '📝 **Additional Notes**'
    report += f'\n{additional_notes}\n'

    return report

# %%
time_log = '09:00 - 13:00: Training\n' +\
                '13:30 - 14:30: Lunch Break\n' +\
                '14:30 - 17:00: Self-Study'

# time_log = '08:00 - 09:00: Self-Study\n' +\
#                 '09:00 - 13:00: Training\n' +\
#                 '13:00 - 14:00: Lunch Break\n' +\
#                 '14:30 - 15:50: Soft-Skills\n' +\
#                 '15:50 - 17:00: Training Session'

# %%
morning_study = ''
training = 'We started the morning off with covering Bayes\' Theorem as well as related ideas such as priors. We then followed alongside Jaime, coding on our own ends at the same time as him to implement both Naive and Non-Naive Bayes\' Classifiers.'
afternoon_study = 'Did the daily leetcode problem before we had our one on one.'
challenges = ''
plan_tomorrow = 'Get a dataset from Jaime, and work in groups to analyze and make prediction using it.'
additional_notes = ''
# morning_study = ''
# challenges = 'None'
# additional_notes = 'None'

# %%
print(generate_report(time_log, morning_study, training, afternoon_study, challenges, plan_tomorrow, additional_notes))
# Out:
# **Daily Activity Report**
# 09/26/25
# Name: Mikael Huff
# Technology: Data Science (DS)
# CDM: Divesh Gupta
#
# 🕒 **Time Log & Activities**
# 09:00 - 13:00: Training
# 13:30 - 14:30: Lunch Break
# 14:30 - 17:00: Self-Study
#
# ✅ **Summary of Work Done**
# Training:
# We started the morning off with covering Bayes' Theorem as well as related ideas such as priors. We then followed alongside Jaime, coding on our own ends at the same time as him to implement both Naive and Non-Naive Bayes' Classifiers.
#
# Afternoon Self-study:
# Did the daily leetcode problem before we had our one on one.
#
# 🚧 **Issues/Challenges Faced**
#
#
# 📅 **Plan for Tomorrow**
# Get a dataset from Jaime, and work in groups to analyze and make prediction using it.
#
# 📝 **Additional Notes**
