# %%
from datetime import datetime

# %%
def generate_report(time_log, morning_study, training, afternoon_study, challenges, plan_tomorrow, additional_notes='None'):

    report = '**Daily Activity Report**\n'
    report += datetime.today().strftime('%m/%d/%y') + '\n'
    report += 'Name: Mikael Huff\n'
    report += 'Technology: Data Science (DS)\n'
    report += 'CDM: Divesh Gupta\n\n'

    report += '🕒 **Time Log & Activities**\n' 
    report += time_log + '\n\n'
    
    report += '✅ **Summary of Work Done**\n'
    if morning_study != '':
        report += f'Morning Self-study:\n{morning_study}\n\n'
    report += f'Training:\n{training}\n\n'
    report += f'Afternoon Self-study:\n{afternoon_study}\n\n'

    report +='🚧 **Issues/Challenges Faced**'
    report += f'\n{challenges}\n\n'

    if plan_tomorrow != '':
        report += '📅 **Plan for Tomorrow**\n'
        report += f'{plan_tomorrow}\n\n'

    report += '📝 **Additional Notes**'
    report += f'\n{additional_notes}\n'

    return report

# %%
time_log = '08:30 - 09:30 Training\n' +\
                '09:30 - 10:00: Team Meeting\n' +\
                '10:00 - 17:00: Project/Self-Study'

# time_log = '08:00 - 09:00: Self-Study\n' +\
#                 '09:00 - 13:00: Training\n' +\
#                 '13:00 - 14:00: Lunch Break\n' +\
#                 '14:30 - 15:50: Soft-Skills\n' +\
#                 '15:50 - 17:00: Training Session'

# %%
morning_study = ''
training = 'We finished going through time series, along with the code required to perform it. This included decomposing the series, doing stationarity tests, chekcing for autocorellation, and forecasting future results.'
afternoon_study = 'After a short meeting with my team, where we talked about the general overview of the project, and what we wanted to do, I got to work on my tasks. This included finishing up the data prepearting, which contained sorting various videos and consolidating their images into a single dataset, all while keeping a balance in duration and frames between them. I think finished implementing the CNN model to perform object detection, which includes having bounding boxes for all the objects on screen. I then turned these boxes into images and consolidated those into videos. I could also count the amount of boxes per frame to turn this data into a time-series and saved it as csv file for Sami to work on. Then I worked a tiny bit on the presentation as well as some leetcode.'
challenges = ''
plan_tomorrow = 'Check with team, hopefully most if not all the code is done, and we can work on the presentation.'
additional_notes = ''
# morning_study = ''
# challenges = 'None'
# additional_notes = 'None'

# %%
print(generate_report(time_log, morning_study, training, afternoon_study, challenges, plan_tomorrow, additional_notes))
# Out:
# **Daily Activity Report**
# 10/09/25
# Name: Mikael Huff
# Technology: Data Science (DS)
# CDM: Divesh Gupta
#
# 🕒 **Time Log & Activities**
# 08:30 - 09:30 Training
# 09:30 - 10:00: Team Meeting
# 10:00 - 17:00: Project/Self-Study
#
# ✅ **Summary of Work Done**
# Training:
# We finished going through time series, along with the code required to perform it. This included decomposing the series, doing stationarity tests, chekcing for autocorellation, and forecasting future results.
#
# Afternoon Self-study:
# ...
