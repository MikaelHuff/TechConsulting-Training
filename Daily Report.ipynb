# %%
from datetime import datetime

# %%
def generate_report(time_log, morning_study, training, afternoon_study, challenges, plan_tomorrow, additional_notes='None'):

    report = '**Daily Activity Report**\n'
    report += datetime.today().strftime('%m/%d/%y') + '\n'
    report += 'Name: Mikael Huff\n'
    report += 'Technology: Data Science (DS)\n'
    report += 'CDM: Divesh Gupta\n\n'

    report += '🕒 **Time Log & Activities**\n' 
    report += time_log + '\n\n'
    
    report += '✅ **Summary of Work Done**\n'
    if morning_study != '':
        report += f'Morning Self-study:\n{morning_study}\n\n'
    report += f'Training:\n{training}\n\n'
    report += f'Afternoon Self-study:\n{afternoon_study}\n\n'

    report +='🚧 **Issues/Challenges Faced**'
    report += f'\n{challenges}\n\n'

    if plan_tomorrow != '':
        report += '📅 **Plan for Tomorrow**\n'
        report += f'{plan_tomorrow}\n\n'

    report += '📝 **Additional Notes**'
    report += f'\n{additional_notes}\n'

    return report

# %%
time_log = '09:00 - 12:30: Training\n' +\
                '12:30 - 13:30: Lunch Break\n' +\
                '13:30 - 17:00: Self-Study'

# time_log = '08:00 - 09:00: Self-Study\n' +\
#                 '09:00 - 13:00: Training\n' +\
#                 '13:00 - 14:00: Lunch Break\n' +\
#                 '14:30 - 15:50: Soft-Skills\n' +\
#                 '15:50 - 17:00: Training Session'

# %%
morning_study = ''
training = 'For the first part of training, we each made, and then voted for a group name. We then begun our introduction to Neural Networks. We started off by downloading the MNIST dataset, 28x28 black and white images of hand-written digits, and then using naive and non-naive Bayes\' Classifiers to solve them. We then made a simple one layer neural network to show the improvement on this dataset.'
afternoon_study = 'For our first weekly project, we have been given datasets to choose from. I chose to use the titanic survivors dataset, for which I looked through the data to see what it contained, and which variables are the most valuable. I then worked on leetcode for a bit before we talked to you and I switched to the cirrhosis dataset. After looking through this dataset for a bit, I spent the rest of the day fitting a logistic regression model.'
challenges = ''
plan_tomorrow = 'Get more information on the specifics of the weekly project.'
additional_notes = ''
# morning_study = ''
# challenges = 'None'
# additional_notes = 'None'

# %%
print(generate_report(time_log, morning_study, training, afternoon_study, challenges, plan_tomorrow, additional_notes))
# Out:
# **Daily Activity Report**
# 09/29/25
# Name: Mikael Huff
# Technology: Data Science (DS)
# CDM: Divesh Gupta
#
# 🕒 **Time Log & Activities**
# 09:00 - 12:30: Training
# 12:30 - 13:30: Lunch Break
# 13:30 - 17:00: Self-Study
#
# ✅ **Summary of Work Done**
# Training:
# For the first part of training, we each made, and then voted for a group name. We then begun our introduction to Neural Networks. We started off by downloading the MNIST dataset, 28x28 black and white images of hand-written digits, and then using naive and non-naive Bayes' Classifiers to solve them. We then made a simple one layer neural network to show the improvement on this dataset.
#
# Afternoon Self-study:
# ...
