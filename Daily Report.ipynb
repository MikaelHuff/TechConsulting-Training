# %%
from datetime import datetime

# %%
# Out:
# '09/10/25'

# %%
def generate_report(time_log, morning_study, training, afternoon_study, challenges, plan_tomorrow, additional_notes='None'):

    report = '**Daily Activity Report**\n'
    report += datetime.today().strftime('%m/%d/%y') + '\n'
    report += 'Name: Mikael Huff\n'
    report += 'Technology: Data Science (DS)\n'
    report += 'CDM: Divesh Gupta\n\n'

    report += '🕒 **Time Log & Activities**\n' +\
                '08:00 - 09:00: Self-Study\n' +\
                '09:00 - 13:00: Training\n' +\
                '13:00 - 14:00: Lunch Break\n' +\
                '14:00 - 18:00: Training Session\n\n'
    
    report += '✅ **Summary of Work Done**\n'
    if morning_study != '':
        report += f'Morning Self-study:\n{morning_study}\n\n'
    report += f'Training:\n{training}\n\n'
    report += f'Afternoon Self-study:\n{afternoon_study}\n\n'

    report +='🚧 **Issues/Challenges Faced**'
    report += f'\n{challenges}\n\n'

    if plan_tomorrow != '':
        report += '📅 **Plan for Tomorrow**\n'
        report += f'{plan_tomorrow}\n'

    report += '📝 **Additional Notes**'
    report += f'\n{additional_notes}\n'

    return report

# %%
time_log = '08:00 - 09:00: Self-Study\n' +\
                '09:00 - 13:00: Training\n' +\
                '13:00 - 14:00: Lunch Break\n' +\
                '14:00 - 18:00: Training Session'

# time_log = '08:00 - 09:00: Self-Study\n' +\
#                 '09:00 - 13:00: Training\n' +\
#                 '13:00 - 14:00: Lunch Break\n' +\
#                 '14:00 - 18:00: Training Session'

# %%
morning_study = 'Worked on leetcode problems in the morning until training started.'
training = 'We again had Uttam lead the training. For the first part, he went over and checked what we had studied so far. And then we covered CICD and he helped us learn how to use jenkins and proper use of it.'
afternoon_study = 'I finished setting up and learning jenkins and the ideas that Uttam taught us, and then continued on leetcode practicing.'
challenges = 'None'
plan_tomorrow = 'Irfan should be back tomorrow so we will resume learning new ideas off the schedule'
additional_notes = 'None'
# morning_study = ''
# challenges = 'None'
# additional_notes = 'None'

# %%
print(generate_report(time_log, morning_study, training, afternoon_study, challenges, plan_tomorrow, additional_notes))
# Out:
# **Daily Activity Report**
# 09/11/25
# Name: Mikael Huff
# Technology: Data Science (DS)
# CDM: Divesh Gupta
#
# 🕒 **Time Log & Activities**
# 08:00 - 09:00: Self-Study
# 09:00 - 13:00: Training
# 13:00 - 14:00: Lunch Break
# 14:00 - 18:00: Training Session
#
# ✅ **Summary of Work Done**
# Morning Self-study:
# Worked on making a template for easy creation of daily reports using Python.
#
# Training:
# As Irfan did not show up, we talked a bit with Uttam and showed what we had been doing. Afterwards, Amit found a dataset online and we all individually practiced classification algorithms using that. This involved following a similar procedure to what we did with regression, going through data cleaning, exploration, and then model training and evaluation.
#
# Afternoon Self-study:
# ...
