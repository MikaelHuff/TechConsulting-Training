# %%
h = {}

# %%
a=b=0
print(a,b)
# Out:
# 0 0

# %%
def maxSubstrings(word: str) -> int:
    return find_word(word, 0)
        


def find_word(word:str, depth):
    # print(word)
    max_str = 0
    for i in range(3, len(word)):
        if word[0] == word[i]:
            print(word[0:i])
            val = find_word(word[i+3:], depth+1)
            max_str = max(val, max_str)

    return max(max_str, depth)


word = "aadcbbbebb"
maxSubstrings(word)
# Out:
# 0
