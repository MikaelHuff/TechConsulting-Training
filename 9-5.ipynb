# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
import pandas as pd

# %%
data_dict = {
    'Weather': ['Sunny', 'Sunny', 'Sunny', 'Sunny', 'Cloudy', 'Cloudy', 'Cloudy', 'Rainy', 'Rainy', 'Rainy'],
    'Temperature' : ['Hot', 'Hot', 'Mild', 'Cool', 'Hot', 'Mild', 'Cool', 'Mild', 'Cool', 'Cool'],
    'Wind' : ['Weak', 'Strong', 'Weak', 'Weak', 'Weak', 'Strong', 'Strong', 'Weak', 'Weak', 'Strong'],
    'Play' : ['No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No']
}
data = pd.DataFrame(data_dict)

# %%
def entropy(column_name):

# %%
print('Weather: ', entropy('Weather'))
print('Temperature: ', entropy('Temperature'))
print('Wind: ', entropy('Wind'))
print('Play: ', entropy('Play'))
# Out:
# Weather:  1.5709505944546684
# Temperature:  1.5709505944546684
# Wind:  0.9709505944546686
# Play:  0.9709505944546686

# %%
.5 * math.log2(.5) + .5 * math.log2(.5)
# Out:
# -1.0

# %%
data ={}
