# %% [markdown]
# ![image.png](attachment:image.png)

# %%
TP = 1449
FN = 551
FP = 512
TN = 6488
# TP = 6488
# FN = 512
# FP = 551
# TN = 1449
accuracy = (TP + TN) / (TP + TN + FP + FN)
precision = TP / (TP + FP)
recall = TP / (TP + FN)
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# Accuracy: 0.8818888888888889
# Precision: 0.7389087200407956
# Recall: 0.7245
